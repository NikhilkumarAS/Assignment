# %% [markdown]
# # Read the dataset to python environment

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_excel(r"C:\Users\Vimal\Desktop\DAS\week 3\iris.xls")

# %%
df
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # Display the columns in the dataset.

# %%
df.SL
# Out:
# 0      5.1
# 1      4.9
# 2      4.7
# 3      4.6
# 4      5.0
#       ...
# 145    6.7
# 146    6.3
# 147    6.5
# 148    6.2
# 149    5.9
# Name: SL, Length: 150, dtype: float64

# %%
df.SW
# Out:
# 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
#       ...
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: SW, Length: 150, dtype: float64

# %%
df['PL']
# Out:
# 0      1.4
# 1      1.4
# 2      1.3
# 3      1.5
# 4      1.4
#       ...
# 145    5.2
# 146    5.0
# 147    5.2
# 148    5.4
# 149    5.1
# Name: PL, Length: 150, dtype: float64

# %%
df.PW
# Out:
# 0      0.2
# 1      0.2
# 2      0.2
# 3      0.2
# 4      0.2
#       ...
# 145    2.3
# 146    1.9
# 147    2.0
# 148    2.3
# 149    1.8
# Name: PW, Length: 150, dtype: float64

# %%
df.Classification
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: Classification, Length: 150, dtype: object

# %% [markdown]
# # Calculate the mean of each column of the dataset.

# %%
df.groupby("Classification").mean()
# Out:
#                     SL     SW     PL     PW
# Classification
# Iris-setosa      5.006  3.418  1.464  0.244
# Iris-versicolor  5.936  2.770  4.260  1.326
# Iris-virginica   6.588  2.974  5.552  2.026

# %%
df.mean()
# Out:
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %% [markdown]
# # Check for the null values present in the dataset

# %%
df.isnull().sum()
# Out:
# SL                0
# SW                0
# PL                0
# PW                0
# Classification    0
# dtype: int64

# %% [markdown]
# # Perform meaningful visualizations using the dataset. Bring at least 3 visualizations.

# %% [markdown]
# # Boxplot

# %%
plt.figure(figsize=(15,20))
plt.subplot(2,2,1).title.set_text('SL V/S Classification')
sns.boxplot(x="Classification",y='SL',data=df)
plt.subplot(2,2,2).title.set_text('SW V/S Classification')
sns.boxplot(x="Classification",y='SW',data=df)
plt.subplot(2,2,3).title.set_text('PL V/S Classification')
sns.boxplot(x="Classification",y='PL',data=df)
plt.subplot(2,2,4).title.set_text('PW V/S Classification')
sns.boxplot(x="Classification",y='PW',data=df)
plt.show()

# %% [markdown]
# Box plot shows that
# Iris setosa SL,PL,PW values are very small compair to other two classification but its SW value is higher than other classes.
#
# Iris virginica Sl,PL,PW values are higher than other classification but its Sw value range come between the other two classes.
#
# Iris-versicolor All values except SW came between other two classification's value its SW value lower than other two classification.
#
# Its shows that Sw value of all three classification behave differently to others

# %% [markdown]
# # Sripplot

# %%
plt.figure(figsize=(15,10))
plt.subplot(2,1,1).title.set_text('SW V/S SL Based on Classification')
sns.stripplot(x="SL",y="SW",hue="Classification",data=df)
plt.subplot(2,1,2).title.set_text('PW V/S PL Based on Classification')
sns.stripplot(x="PL",y="PW",hue="Classification",data=df)
plt.show()

# %% [markdown]
# SL v/s SW plot shows that for setosa values are in specific range. but other two classification some values mixed in certaiin range.
# PL/PW plot clearly show the difference between the different classification's

# %% [markdown]
# # Pairplot

# %%
plt.figure(figsize=(20,15))
p=sns.pairplot(df,hue="Classification")
p.fig.suptitle("Relation b/w SL,SW,PL,PW",y=1.08)
plt.show()

# %% [markdown]
# The pairplot shows the relationship between SL,SW,PL,PW based on classification

# %% [markdown]
# # Histogram

# %%
plt.figure(figsize=(10,8))
plt.hist(df.SL)
plt.title("SL")
plt.xlabel("SL Values")
plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize=(10,8))
plt.hist(df.SW)
plt.title("SW")
plt.xlabel("SW Values")
plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize=(10,8))
plt.hist(df.PL)
plt.title("PL")
plt.xlabel("PL Values")
plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize=(10,8))
plt.hist(df.PW)
plt.title("PW")
plt.xlabel("PW Values")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# The histograms of SL,SW,PL,PW shows how its values are distributed. SL and SW values are continuous but PL and PW values are not they kind of have two sets of values

# %% [markdown]
# # Heatmaps

# %%
plt.figure(figsize=(10,8))
plt.title("Heat Map of Correlation between SL,SW,PL,PW")
sns.heatmap(df.corr(),annot=True,cmap="Blues")
plt.show()

# %% [markdown]
# The heat map shows the correlation between SL,SW,PL,PW irrespective of Claasification

# %% [markdown]
# # Heatmaps of Each Group

# %%
sub=df.groupby("Classification")
Is=sub.get_group('Iris-setosa')
Iv=sub.get_group('Iris-versicolor')
Ig=sub.get_group('Iris-virginica')

# %%
plt.figure(figsize=(10,8))
plt.title("Iris-setosa")
sns.heatmap(Is.corr(),annot=True,cmap="Blues")
plt.show()

# %% [markdown]
# The heat map shows the correlation between SL,SW,PL,PW based on Iris-setosa group
# SW & SL show strong relation

# %%
plt.figure(figsize=(10,8))
plt.title("Iris-versicolor")
sns.heatmap(Iv.corr(),annot=True,cmap="Blues")
plt.show()

# %% [markdown]
# The heat map shows the correlation between SL,SW,PL,PW based on Iris-versicolor group
# PL&PW, PL&SL show strong relation

# %%
plt.figure(figsize=(10,8))
plt.title("Iris-virginica")
sns.heatmap(Ig.corr(),annot=True,cmap="Blues")
plt.show()

# %% [markdown]
# The heat map shows the correlation between SL,SW,PL,PW based on Iris-virginica group
# SL and PL show strong relation
